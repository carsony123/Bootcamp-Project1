# %%
# Dependencies
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd
import json
import requests

# %%
csvpath = 'WHO-COVID-19-global-data.csv'
data = pd.read_csv(csvpath)
data.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %%
len(data)
# Out:
# 266388

# %%
data.groupby('Country').max().head()
# Out:
#                Date_reported Country_code WHO_region  New_cases  \
# Country
# Afghanistan       2023-01-30           AF       EMRO       3243
# Albania           2023-01-30           AL       EURO       2832
# Algeria           2023-01-30           DZ       AFRO       2521
# American Samoa    2023-01-30           AS       WPRO        955
# Andorra           2023-01-30           AD       EURO       1676
#
#                 Cumulative_cases  New_deaths  Cumulative_deaths
# Country
# Afghanistan               208452         159               7876
# Albania                   333223          21               3596
# Algeria                   271364          49               6881
# American Samoa              8320           5                 34
# Andorra                    47839           6                159

# %%
data['Date_reported'].astype(str)
# Out:
# 0         2020-01-03
# 1         2020-01-04
# 2         2020-01-05
# 3         2020-01-06
# 4         2020-01-07
#              ...
# 266383    2023-01-26
# 266384    2023-01-27
# 266385    2023-01-28
# 266386    2023-01-29
# 266387    2023-01-30
# Name: Date_reported, Length: 266388, dtype: object

# %%
US_data = data.loc[data['Country'] == 'United States of America']
US_data_reduced = US_data.loc(str(US_data['Date_reported'].replace('-', '')).astype(int) > 20200100 & < 202300000) )
US_data.head()
# Out:
#   File "C:\Users\Owner\AppData\Local\Temp\ipykernel_15436\3582540368.py", line 2
#     US_data_reduced = US_data.loc(str(US_data['Date_reported'].replace('-', '')).astype(int) > 20200100 & < 202300000) )
#                                                                                                           ^
# SyntaxError: invalid syntax

# %%
US_data.plot('Date_reported', 'New_cases')
plt.ylabel('New Cases')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15436\764306795.py in <module>
# ----> 1 US_data.plot('Date_reported', 'New_cases')
#       2 plt.ylabel('New Cases')
#
# NameError: name 'US_data' is not defined

# %%
topic = 'colleges'
source = 'ccd'
endpoint = 'directory'
year = '2021'

url = f'https://educationdata.urban.org/api/v1/college-university/ipeds/enrollment-headcount/{year}/1/'

print(url)
response = requests.get(url)
print(response)
data = response.json()
data
# Out:
# https://educationdata.urban.org/api/v1/college-university/ipeds/enrollment-headcount/2021/1/
# <Response [200]>
# {'count': 174060,
#  'next': 'https://educationdata.urban.org/api/v1/college-university/ipeds/enrollment-headcount/2021/1/?page=2',
#  'previous': None,
#  'results': [{'unitid': 100654,
#    'fips': 1,
#    'year': 2021,
#    'level_of_study': 1,
#    'race': 1,
#    'sex': 1,
#    'headcount': 59},
#   {'unitid': 100654,
#    'fips': 1,
#    'year': 2021,
#    'level_of_study': 1,
#    'race': 1,
#    'sex': 99,
#    'headcount': 102},
#   {'unitid': 100654,
#    'fips': 1,
#    'year': 2021,
#    'level_of_study': 1,
#    'race': 1,
#    'sex': 2,
#    'headcount': 43},
#   {'unitid': 100663,
#    'fips': 1,
#    'year': 2021,
#    'level_of_study': 1,
#    'race': 1,
#    'sex': 1,
#    'headcount': 3440},
#   {'unitid': 100663,
#    'fips': 1,
#    'year': 2021,
#    'level_of_study': 1,
#    'race': 1,
#    'sex': 99,
#    'headcount': 8575},
#   {'unitid': 100663,
# ...

# %%
baseurl = 'https://educationdata.urban.org/api/v1/college-university/ipeds/enrollment-headcount/summaries?'
params = {
    'var': 'headcount',
    'stat': 'sum',
    'by': 'unitid',
    # 1—Undergraduate 2—Graduate 3—First professional 4—Postbaccalaureate 99—Total
    'level_of_study': '99',
    'year': '2020'
}

response = requests.get(baseurl, params=params)
print(response)
data = response.json()
data
# Out:
# <Response [200]>
# {'count': 6169,
#  'next': None,
#  'previous': None,
#  'results': [{'year': 2020, 'unitid': 100654, 'headcount': 6560},
#   {'year': 2020, 'unitid': 100663, 'headcount': 25843},
#   {'year': 2020, 'unitid': 100690, 'headcount': 1079},
#   {'year': 2020, 'unitid': 100706, 'headcount': 11312},
#   {'year': 2020, 'unitid': 100724, 'headcount': 4640},
#   {'year': 2020, 'unitid': 100751, 'headcount': 42096},
#   {'year': 2020, 'unitid': 100760, 'headcount': 2325},
#   {'year': 2020, 'unitid': 100812, 'headcount': 3878},
#   {'year': 2020, 'unitid': 100830, 'headcount': 6199},
#   {'year': 2020, 'unitid': 100858, 'headcount': 32840},
#   {'year': 2020, 'unitid': 100937, 'headcount': 1237},
#   {'year': 2020, 'unitid': 101028, 'headcount': 2075},
#   {'year': 2020, 'unitid': 101116, 'headcount': 594},
#   {'year': 2020, 'unitid': 101143, 'headcount': 2525},
#   {'year': 2020, 'unitid': 101161, 'headcount': 9883},
# ...
